# %% [markdown]
# 8.    ALZHEIMER'S DISEASE AND HEALTHY AGING DATA
#
#
# TEAM ID:01
# SEM:04
# DIV:D
# DEPT:COMPUTER SCIENCE
#
#
#    NAME                  USN            ROLL NO
#   JANVI CHINCHANSUR    01FE22BCS003        402
#   ANANYA M PATIL       01FE22BCS020        406
#   AKHILA JAYA          01FE22BCS019        407
#   TANUJA TONDIKATTI    01FE22BCS182        430

# %%
#importing libraries numpy and pandas
import numpy as np
import pandas as pd

# %%
#reading csv file using pandas
dataset=pd.read_csv('Alzheimer_s_Disease_and_Healthy_Aging_Data.csv')
# first five rows of dataset
dataset.head()
# Out:
# C:\Users\JANVI\AppData\Local\Temp\ipykernel_22320\2046931971.py:2: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset=pd.read_csv('Alzheimer_s_Disease_and_Healthy_Aging_Data.csv')
#                                         RowId  YearStart  YearEnd  \
# 0  BRFSS~2015~2015~9004~Q43~TOC11~AGE~OVERALL       2015     2015
# 1  BRFSS~2019~2019~9004~Q27~TMC03~AGE~OVERALL       2019     2019
# 2   BRFSS~2019~2019~9004~Q43~TOC11~AGE~GENDER       2019     2019
# 3  BRFSS~2019~2019~9004~Q43~TOC11~AGE~OVERALL       2019     2019
# 4   BRFSS~2015~2015~9004~Q43~TOC11~AGE~GENDER       2015     2015
#
#   LocationAbbr LocationDesc Datasource           Class  \
# 0         WEST         West      BRFSS  Overall Health
# 1         WEST         West      BRFSS   Mental Health
# 2         WEST         West      BRFSS  Overall Health
# 3         WEST         West      BRFSS  Overall Health
# ...

# %%
#shape of the dataset(i.e no of rows and columns)
dataset.shape
# Out:
# (250937, 31)

# %% [markdown]
# The given dataset has 250937 rows and 31 columns.some of the attributes are
# YearStart,YearEnd,LocationAbbr,LocationDesc and many more.

# %%
#Differentiating categorical attributes and numerical attributes
# Categorical columns
cat_col = [col for col in dataset.columns if dataset[col].dtype == 'object']
print('Categorical columns :\n',cat_col)
# Numerical columns
num_col = [col for col in dataset.columns if dataset[col].dtype != 'object']
print('Numerical columns :\n',num_col)
# Out:
# Categorical columns :
#  ['RowId', 'LocationAbbr', 'LocationDesc', 'Datasource', 'Class', 'Topic', 'Question', 'Data_Value_Unit', 'DataValueTypeID', 'Data_Value_Type', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit', 'StratificationCategory1', 'Stratification1', 'StratificationCategory2', 'Stratification2', 'Geolocation', 'ClassID', 'TopicID', 'QuestionID', 'StratificationCategoryID1', 'StratificationID1', 'StratificationCategoryID2', 'StratificationID2']
# Numerical columns :
#  ['YearStart', 'YearEnd', 'Data_Value', 'Data_Value_Alt', 'LocationID']

# %% [markdown]
# Attribute which has Datatype as object,then it is considered as categorical attribute.We have 26 categorical attributes and 5 numerical attributes.

# %%
#describe() for getting statistical properties of dataset(i.e mean,median,mode..etc)
dataset.describe()
# Out:
#            YearStart        YearEnd     Data_Value  Data_Value_Alt  \
# count  250937.000000  250937.000000  169302.000000   169302.000000
# mean     2017.940933    2018.169716      37.328349       37.328349
# std         2.031564       2.081039      25.213181       25.213181
# min      2015.000000    2015.000000       0.000000        0.000000
# 25%      2016.000000    2016.000000      15.700000       15.700000
# 50%      2018.000000    2018.000000      32.300000       32.300000
# 75%      2020.000000    2020.000000      56.000000       56.000000
# max      2021.000000    2021.000000     100.000000      100.000000
#
#           LocationID
# count  250937.000000
# mean      793.866437
# std      2502.174327
# min         1.000000
# 25%        19.000000
# 50%        34.000000
# 75%        49.000000
# max      9004.000000

# %% [markdown]
# From this,we came to know that
# start year:2015   ending year:2021   total count=149324

# %% [markdown]
# 1.  DATA CLEANING

# %%
# Find rows with any NaN
any_nan_df = dataset[dataset.isna().any(axis=1)]
any_nan_df.head()
# Out:
#                                         RowId  YearStart  YearEnd  \
# 0  BRFSS~2015~2015~9004~Q43~TOC11~AGE~OVERALL       2015     2015
# 1  BRFSS~2019~2019~9004~Q27~TMC03~AGE~OVERALL       2019     2019
# 2   BRFSS~2019~2019~9004~Q43~TOC11~AGE~GENDER       2019     2019
# 3  BRFSS~2019~2019~9004~Q43~TOC11~AGE~OVERALL       2019     2019
# 4   BRFSS~2015~2015~9004~Q43~TOC11~AGE~GENDER       2015     2015
#
#   LocationAbbr LocationDesc Datasource           Class  \
# 0         WEST         West      BRFSS  Overall Health
# 1         WEST         West      BRFSS   Mental Health
# 2         WEST         West      BRFSS  Overall Health
# 3         WEST         West      BRFSS  Overall Health
# 4         WEST         West      BRFSS  Overall Health
#
#                               Topic  \
# 0      Arthritis among older adults
# 1  Lifetime diagnosis of depression
# 2      Arthritis among older adults
# 3      Arthritis among older adults
# 4      Arthritis among older adults
#
# ...

# %%
#shape of nan(missing values) dataset
print(any_nan_df.shape)
print('Looks like there are '+str(any_nan_df.shape[0])+' rows with atleast one NaN!')
print('percentage of atleast one NaN='+str((any_nan_df.shape[0]/dataset.shape[0])*100))
# Out:
# (249886, 31)
# Looks like there are 249886 rows with atleast one NaN!
# percentage of atleast one NaN=99.58116977568075

# %% [markdown]
# Dataset contains 249886 rows with atleast one NaN attribute.Percentage of NaN was 99.58%

# %%
#check if our data contains any missing values or not by isnull()
dataset.isnull().sum()
# Out:
# RowId                              0
# YearStart                          0
# YearEnd                            0
# LocationAbbr                       0
# LocationDesc                       0
# Datasource                         0
# Class                              0
# Topic                              0
# Question                           0
# Data_Value_Unit                    0
# DataValueTypeID                    0
# Data_Value_Type                    0
# Data_Value                     81635
# Data_Value_Alt                 81635
# Data_Value_Footnote_Symbol    151823
# Data_Value_Footnote           151823
# Low_Confidence_Limit           81785
# High_Confidence_Limit          81785
# StratificationCategory1            0
# Stratification1                    0
# StratificationCategory2        32376
# Stratification2                32376
# Geolocation                    26709
# ClassID                            0
# TopicID                            0
# ...

# %% [markdown]
#  Missing values can occur when no information is provided for one or more items or for a whole unit. We will use the isnull() method.It will give columnwise count.From this,Data_Value_Footnote and Data_Value_Footnote_symbol has more number of null values.

# %% [markdown]
# 2. Checking Duplicates

# %%
#if our dataset contains any duplicates or not
duplicates = dataset.duplicated()
print(duplicates)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 250932    False
# 250933    False
# 250934    False
# 250935    False
# 250936    False
# Length: 250937, dtype: bool

# %% [markdown]
# There is no duplicate rows in this dataset.Pandas drop_duplicates() method helps in removing duplicates from the data frame.

# %% [markdown]
# 3. Dropping unwanted columns
#    Data_Value_Footnote_Symbol and Data_Value_Footnote has more number(151823) missing values. Out of 250937 tuples we have 151823 tuples with nan values, if we fill all this values it may lead result to misleading. It is not easy to fill the missing values so dropping is the suitable option. However Data_Value_Footnote explains method of data collection we are not concerned about data collection so we dropped the column.

# %%
dataset1=dataset.drop(columns='Data_Value_Footnote')
dataset1.dropna(subset=['Data_Value_Footnote_Symbol'], axis=0, inplace=True)
dataset1.shape
# Out:
# (99114, 30)

# %%
dataset1.head
# Out:
# <bound method NDFrame.head of                                         RowId  YearStart  YearEnd  \
# 147     BRFSS~2018~2018~10~Q17~TAC01~AGE~RACE       2018     2018
# 149     BRFSS~2019~2019~13~Q19~TSC04~AGE~RACE       2019     2019
# 177     BRFSS~2015~2015~16~Q09~TSC09~AGE~RACE       2015     2015
# 204     BRFSS~2019~2019~21~Q03~TMC01~AGE~RACE       2019     2019
# 206     BRFSS~2016~2016~22~Q03~TMC01~AGE~RACE       2016     2016
# ...                                       ...        ...      ...
# 250920  BRFSS~2019~2019~59~Q14~TSC06~AGE~RACE       2019     2019
# 250926  BRFSS~2019~2019~59~Q04~TOC04~AGE~RACE       2019     2019
# 250929  BRFSS~2019~2019~59~Q01~TNC01~AGE~RACE       2019     2019
# 250932  BRFSS~2015~2015~49~Q22~TSC07~AGE~RACE       2015     2015
# 250935  BRFSS~2018~2018~49~Q16~TNC03~AGE~RACE       2018     2018
#
#        LocationAbbr                     LocationDesc Datasource  \
# 147              DE                         Delaware      BRFSS
# ...

# %%
#Information about the DataFrame, including data types, memory usage, and presence of missing values.
dataset=dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99114 entries, 147 to 250935
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RowId                       99114 non-null  object
#  1   YearStart                   99114 non-null  int64
#  2   YearEnd                     99114 non-null  int64
#  3   LocationAbbr                99114 non-null  object
#  4   LocationDesc                99114 non-null  object
#  5   Datasource                  99114 non-null  object
#  6   Class                       99114 non-null  object
#  7   Topic                       99114 non-null  object
#  8   Question                    99114 non-null  object
#  9   Data_Value_Unit             99114 non-null  object
#  10  DataValueTypeID             99114 non-null  object
#  11  Data_Value_Type             99114 non-null  object
#  12  Data_Value                  17479 non-null  float64
# ...

# %% [markdown]
# Still some attributes has null entries.For example Data_Value,Data_Value_Alt,
# Low_Confidence_Limit and High_Confidence_Limit has only 8210 non-null rows.

# %%
dataset1.head
# Out:
# <bound method NDFrame.head of                                         RowId  YearStart  YearEnd  \
# 147     BRFSS~2018~2018~10~Q17~TAC01~AGE~RACE       2018     2018
# 149     BRFSS~2019~2019~13~Q19~TSC04~AGE~RACE       2019     2019
# 177     BRFSS~2015~2015~16~Q09~TSC09~AGE~RACE       2015     2015
# 204     BRFSS~2019~2019~21~Q03~TMC01~AGE~RACE       2019     2019
# 206     BRFSS~2016~2016~22~Q03~TMC01~AGE~RACE       2016     2016
# ...                                       ...        ...      ...
# 250920  BRFSS~2019~2019~59~Q14~TSC06~AGE~RACE       2019     2019
# 250926  BRFSS~2019~2019~59~Q04~TOC04~AGE~RACE       2019     2019
# 250929  BRFSS~2019~2019~59~Q01~TNC01~AGE~RACE       2019     2019
# 250932  BRFSS~2015~2015~49~Q22~TSC07~AGE~RACE       2015     2015
# 250935  BRFSS~2018~2018~49~Q16~TNC03~AGE~RACE       2018     2018
#
#        LocationAbbr                     LocationDesc Datasource  \
# 147              DE                         Delaware      BRFSS
# ...

# %% [markdown]
#    DATA REDUCTION

# %%
mean_Data_Value = dataset1['Data_Value'].mean()
dataset1['Data_Value'] = dataset1['Data_Value'].fillna(mean_Data_Value)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99114 entries, 147 to 250935
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RowId                       99114 non-null  object
#  1   YearStart                   99114 non-null  int64
#  2   YearEnd                     99114 non-null  int64
#  3   LocationAbbr                99114 non-null  object
#  4   LocationDesc                99114 non-null  object
#  5   Datasource                  99114 non-null  object
#  6   Class                       99114 non-null  object
#  7   Topic                       99114 non-null  object
#  8   Question                    99114 non-null  object
#  9   Data_Value_Unit             99114 non-null  object
#  10  DataValueTypeID             99114 non-null  object
#  11  Data_Value_Type             99114 non-null  object
#  12  Data_Value                  99114 non-null  float64
# ...

# %%
mean_Data_Value_Alt = dataset1['Data_Value_Alt'].mean()
dataset1['Data_Value_Alt'] = dataset1['Data_Value_Alt'].fillna(mean_Data_Value_Alt)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99114 entries, 147 to 250935
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RowId                       99114 non-null  object
#  1   YearStart                   99114 non-null  int64
#  2   YearEnd                     99114 non-null  int64
#  3   LocationAbbr                99114 non-null  object
#  4   LocationDesc                99114 non-null  object
#  5   Datasource                  99114 non-null  object
#  6   Class                       99114 non-null  object
#  7   Topic                       99114 non-null  object
#  8   Question                    99114 non-null  object
#  9   Data_Value_Unit             99114 non-null  object
#  10  DataValueTypeID             99114 non-null  object
#  11  Data_Value_Type             99114 non-null  object
#  12  Data_Value                  99114 non-null  float64
# ...

# %%
#filling missing values with most repeated values  
mode_Low_Confidence_Limit = dataset1['Low_Confidence_Limit'].mode()[0]
dataset1['Low_Confidence_Limit'] = dataset1['Low_Confidence_Limit'].fillna(mode_Low_Confidence_Limit)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99114 entries, 147 to 250935
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RowId                       99114 non-null  object
#  1   YearStart                   99114 non-null  int64
#  2   YearEnd                     99114 non-null  int64
#  3   LocationAbbr                99114 non-null  object
#  4   LocationDesc                99114 non-null  object
#  5   Datasource                  99114 non-null  object
#  6   Class                       99114 non-null  object
#  7   Topic                       99114 non-null  object
#  8   Question                    99114 non-null  object
#  9   Data_Value_Unit             99114 non-null  object
#  10  DataValueTypeID             99114 non-null  object
#  11  Data_Value_Type             99114 non-null  object
#  12  Data_Value                  99114 non-null  float64
# ...

# %%
mode_High_Confidence_Limit = dataset1['High_Confidence_Limit'].mode()[0]
dataset1['High_Confidence_Limit'] = dataset1['High_Confidence_Limit'].fillna(mode_High_Confidence_Limit)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99114 entries, 147 to 250935
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RowId                       99114 non-null  object
#  1   YearStart                   99114 non-null  int64
#  2   YearEnd                     99114 non-null  int64
#  3   LocationAbbr                99114 non-null  object
#  4   LocationDesc                99114 non-null  object
#  5   Datasource                  99114 non-null  object
#  6   Class                       99114 non-null  object
#  7   Topic                       99114 non-null  object
#  8   Question                    99114 non-null  object
#  9   Data_Value_Unit             99114 non-null  object
#  10  DataValueTypeID             99114 non-null  object
#  11  Data_Value_Type             99114 non-null  object
#  12  Data_Value                  99114 non-null  float64
# ...

# %%
#filling missing value with most repeated values in stratificationcategory2 attribute
mode_StratificationCategory2  = dataset1['StratificationCategory2'].mode()[0]
dataset1['StratificationCategory2'] = dataset1['StratificationCategory2'].fillna(mode_StratificationCategory2)

#filling missing value with most repeated values in stratification2 attribute
mode_Stratification2 = dataset1['Stratification2'].mode()[0]
dataset1['Stratification2'] = dataset1['Stratification2'].fillna(mode_Stratification2)

#filling missing value with most repeated values in geolocation attribute
mode_Geolocation = dataset1['Geolocation'].mode()[0]
dataset1['Geolocation'] = dataset1['Geolocation'].fillna(mode_Geolocation)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99114 entries, 147 to 250935
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RowId                       99114 non-null  object
#  1   YearStart                   99114 non-null  int64
#  2   YearEnd                     99114 non-null  int64
#  3   LocationAbbr                99114 non-null  object
#  4   LocationDesc                99114 non-null  object
#  5   Datasource                  99114 non-null  object
#  6   Class                       99114 non-null  object
#  7   Topic                       99114 non-null  object
#  8   Question                    99114 non-null  object
#  9   Data_Value_Unit             99114 non-null  object
#  10  DataValueTypeID             99114 non-null  object
#  11  Data_Value_Type             99114 non-null  object
#  12  Data_Value                  99114 non-null  float64
# ...

# %% [markdown]
#     DATA TRANSFORMATION

# %% [markdown]
# Normalization and standardization are two common techniques used in data preprocessing to transform features in a dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data from the CSV file
data = pd.read_csv('Alzheimer_s_Disease_and_Healthy_Aging_Data.csv')
data
# Out:
# C:\Users\JANVI\AppData\Local\Temp\ipykernel_22320\1411624840.py:2: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Alzheimer_s_Disease_and_Healthy_Aging_Data.csv')
#                                              RowId  YearStart  YearEnd  \
# 0       BRFSS~2015~2015~9004~Q43~TOC11~AGE~OVERALL       2015     2015
# 1       BRFSS~2019~2019~9004~Q27~TMC03~AGE~OVERALL       2019     2019
# 2        BRFSS~2019~2019~9004~Q43~TOC11~AGE~GENDER       2019     2019
# 3       BRFSS~2019~2019~9004~Q43~TOC11~AGE~OVERALL       2019     2019
# 4        BRFSS~2015~2015~9004~Q43~TOC11~AGE~GENDER       2015     2015
# ...                                            ...        ...      ...
# 250932       BRFSS~2015~2015~49~Q22~TSC07~AGE~RACE       2015     2015
# 250933    BRFSS~2018~2018~49~Q46~TOC10~AGE~OVERALL       2018     2018
# 250934       BRFSS~2015~2015~49~Q18~TSC08~AGE~RACE       2015     2015
# ...

# %%
print(dataset1.head())
# Out:
#                                      RowId  YearStart  YearEnd LocationAbbr  \
# 147  BRFSS~2018~2018~10~Q17~TAC01~AGE~RACE       2018     2018           DE
# 149  BRFSS~2019~2019~13~Q19~TSC04~AGE~RACE       2019     2019           GA
# 177  BRFSS~2015~2015~16~Q09~TSC09~AGE~RACE       2015     2015           ID
# 204  BRFSS~2019~2019~21~Q03~TMC01~AGE~RACE       2019     2019           KY
# 206  BRFSS~2016~2016~22~Q03~TMC01~AGE~RACE       2016     2016           LA
#
#     LocationDesc Datasource                    Class  \
# 147     Delaware      BRFSS  Smoking and Alcohol Use
# 149      Georgia      BRFSS  Screenings and Vaccines
# 177        Idaho      BRFSS  Screenings and Vaccines
# 204     Kentucky      BRFSS            Mental Health
# 206    Louisiana      BRFSS            Mental Health
#
#                                       Topic  \
# 147                         Current smoking
# 149  Diabetes screening within past 3 years
# 177           Ever had pneumococcal vaccine
# ...

# %%
import pandas as pd
# Merge two columns
dataset1['Location'] = dataset1['LocationAbbr'].astype(str) + dataset1['LocationDesc']

# Display the DataFrame with merged column
dataset1.head()
# Out:
#                                      RowId  YearStart  YearEnd LocationAbbr  \
# 147  BRFSS~2018~2018~10~Q17~TAC01~AGE~RACE       2018     2018           DE
# 149  BRFSS~2019~2019~13~Q19~TSC04~AGE~RACE       2019     2019           GA
# 177  BRFSS~2015~2015~16~Q09~TSC09~AGE~RACE       2015     2015           ID
# 204  BRFSS~2019~2019~21~Q03~TMC01~AGE~RACE       2019     2019           KY
# 206  BRFSS~2016~2016~22~Q03~TMC01~AGE~RACE       2016     2016           LA
#
#     LocationDesc Datasource                    Class  \
# 147     Delaware      BRFSS  Smoking and Alcohol Use
# 149      Georgia      BRFSS  Screenings and Vaccines
# 177        Idaho      BRFSS  Screenings and Vaccines
# 204     Kentucky      BRFSS            Mental Health
# 206    Louisiana      BRFSS            Mental Health
#
#                                       Topic  \
# 147                         Current smoking
# 149  Diabetes screening within past 3 years
# 177           Ever had pneumococcal vaccine
# ...

# %%
import pandas as pd
# Delete a column
dataset1.drop(columns=['LocationAbbr'], inplace=True)
dataset1.head()
# Out:
#                                      RowId  YearStart  YearEnd LocationDesc  \
# 147  BRFSS~2018~2018~10~Q17~TAC01~AGE~RACE       2018     2018     Delaware
# 149  BRFSS~2019~2019~13~Q19~TSC04~AGE~RACE       2019     2019      Georgia
# 177  BRFSS~2015~2015~16~Q09~TSC09~AGE~RACE       2015     2015        Idaho
# 204  BRFSS~2019~2019~21~Q03~TMC01~AGE~RACE       2019     2019     Kentucky
# 206  BRFSS~2016~2016~22~Q03~TMC01~AGE~RACE       2016     2016    Louisiana
#
#     Datasource                    Class  \
# 147      BRFSS  Smoking and Alcohol Use
# 149      BRFSS  Screenings and Vaccines
# 177      BRFSS  Screenings and Vaccines
# 204      BRFSS            Mental Health
# 206      BRFSS            Mental Health
#
#                                       Topic  \
# 147                         Current smoking
# 149  Diabetes screening within past 3 years
# 177           Ever had pneumococcal vaccine
# 204                Frequent mental distress
# ...

# %%
import pandas as pd
# Delete a column
dataset1.drop(columns=['LocationDesc'], inplace=True)
dataset1.head()
# Out:
#                                      RowId  YearStart  YearEnd Datasource  \
# 147  BRFSS~2018~2018~10~Q17~TAC01~AGE~RACE       2018     2018      BRFSS
# 149  BRFSS~2019~2019~13~Q19~TSC04~AGE~RACE       2019     2019      BRFSS
# 177  BRFSS~2015~2015~16~Q09~TSC09~AGE~RACE       2015     2015      BRFSS
# 204  BRFSS~2019~2019~21~Q03~TMC01~AGE~RACE       2019     2019      BRFSS
# 206  BRFSS~2016~2016~22~Q03~TMC01~AGE~RACE       2016     2016      BRFSS
#
#                        Class                                   Topic  \
# 147  Smoking and Alcohol Use                         Current smoking
# 149  Screenings and Vaccines  Diabetes screening within past 3 years
# 177  Screenings and Vaccines           Ever had pneumococcal vaccine
# 204            Mental Health                Frequent mental distress
# 206            Mental Health                Frequent mental distress
#
#                                               Question Data_Value_Unit  \
# ...

# %%
dataset1.shape
# Out:
# (99114, 29)

# %%
# Visualization 1: Distribution of Cases by Year
plt.figure(figsize=(10, 6))
sns.countplot(x='YearStart', data=data, palette='viridis')
plt.title('Distribution of Cases by Year')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.show()

# %%
# Find the year with the highest number of cases
year_with_max_cases = data['YearStart'].value_counts().idxmax()
year_with_max_cases
# Out:
# 2016

# %%
# Filter data for the year with the highest number of cases
data_max_year = data[data['YearStart'] == year_with_max_cases]

# %%
data_max_year['Stratification1'] = data_max_year['Stratification1'].astype('category')
# Out:
# C:\Users\JANVI\AppData\Local\Temp\ipykernel_22320\142712538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_max_year['Stratification1'] = data_max_year['Stratification1'].astype('category')

# %%
# Visualization 2: Distribution of Cases by Gender for the Year with the Highest Cases
plt.figure(figsize=(10, 6))
sns.histplot(data=data_max_year, x='Stratification1', palette='pastel', kde=False, discrete=True)
plt.title(f'Distribution of Cases by Gender in {year_with_max_cases}')
plt.xlabel('Gender')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\JANVI\AppData\Local\Temp\ipykernel_22320\1748218563.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=data_max_year, x='Stratification1', palette='pastel', kde=False, discrete=True)

# %%
# Find the gender with the highest number of cases in that year
gender_with_max_cases = data_max_year['Stratification1'].value_counts().idxmax()
gender_with_max_cases
# Out:
# 'Overall'

# %%
# Filter data for the gender with the highest number of cases in that year
data_max_gender = data_max_year[data_max_year['Stratification1'] == gender_with_max_cases]
data_max_gender
# Out:
#                                            RowId  YearStart  YearEnd  \
# 19      BRFSS~2016~2016~56~Q35~TOC03~AGE~OVERALL       2016     2016
# 129      BRFSS~2016~2016~05~Q34~TOC09~AGE~GENDER       2016     2016
# 136     BRFSS~2016~2016~05~Q27~TMC03~AGE~OVERALL       2016     2016
# 150        BRFSS~2016~2016~66~Q03~TMC01~AGE~RACE       2016     2016
# 155      BRFSS~2016~2016~66~Q03~TMC01~AGE~GENDER       2016     2016
# ...                                          ...        ...      ...
# 250848   BRFSS~2016~2016~48~Q40~TGC05~AGE~GENDER       2016     2016
# 250855     BRFSS~2016~2016~59~Q39~TGC04~AGE~RACE       2016     2016
# 250880     BRFSS~2016~2016~51~Q05~TOC06~AGE~RACE       2016     2016
# 250904     BRFSS~2016~2016~49~Q18~TSC08~AGE~RACE       2016     2016
# 250911     BRFSS~2016~2016~51~Q07~TOC05~AGE~RACE       2016     2016
#
#        LocationAbbr                     LocationDesc Datasource  \
# 19               WY                          Wyoming      BRFSS
# ...

# %%
# Visualization 3: Distribution of Class IDs for the Gender with the Highest Cases
class_counts = data_max_gender['ClassID'].value_counts()

plt.figure(figsize=(12, 6))
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', colors=sns.color_palette('Set2', len(class_counts)))
plt.title(f'Distribution of Class IDs for {gender_with_max_cases} in {year_with_max_cases}')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %%
class_id_counts = data['ClassID'].value_counts()
class_id_with_max_cases = class_id_counts.idxmax()
class_id_with_max_cases
# Out:
# 'C01'

# %%
# Visualization 4: Distribution of Question IDs for the Most Frequent Class ID
data_max_class_id = data[data['ClassID'] == class_id_with_max_cases]
data_max_class_id
# Out:
#                                              RowId  YearStart  YearEnd  \
# 0       BRFSS~2015~2015~9004~Q43~TOC11~AGE~OVERALL       2015     2015
# 2        BRFSS~2019~2019~9004~Q43~TOC11~AGE~GENDER       2019     2019
# 3       BRFSS~2019~2019~9004~Q43~TOC11~AGE~OVERALL       2019     2019
# 4        BRFSS~2015~2015~9004~Q43~TOC11~AGE~GENDER       2015     2015
# 5          BRFSS~2015~2015~9004~Q43~TOC11~AGE~RACE       2015     2015
# ...                                            ...        ...      ...
# 250928     BRFSS~2018~2018~49~Q05~TOC06~AGE~GENDER       2018     2018
# 250930     BRFSS~2017~2017~59~Q44~TOC12~AGE~GENDER       2017     2017
# 250931       BRFSS~2017~2017~48~Q33~TOC08~AGE~RACE       2017     2017
# 250933    BRFSS~2018~2018~49~Q46~TOC10~AGE~OVERALL       2018     2018
# 250936     BRFSS~2017~2017~59~Q04~TOC04~AGE~GENDER       2017     2017
#
#        LocationAbbr                     LocationDesc Datasource  \
# ...

# %%
topic_counts = data_max_class_id['TopicID'].value_counts().reset_index()
topic_counts.columns = ['TopicID', 'Count']

# %%
# Visualization 4: Scatter Plot of Topic IDs for the Most Frequent Class ID
plt.figure(figsize=(14, 8))
plt.scatter(topic_counts['TopicID'], topic_counts['Count'], color='b')
plt.title(f'Distribution of Topic IDs for Class ID {class_id_with_max_cases}')
plt.xlabel('Topic ID')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualization 5: Distribution of High Confidence Limit and Low Confidence Limit for the Most Frequent Class ID
plt.figure(figsize=(14, 8))
sns.histplot(data_max_class_id, x='High_Confidence_Limit', color='blue', label='High Confidence Limit', kde=True, bins=30)
sns.histplot(data_max_class_id, x='Low_Confidence_Limit', color='red', label='Low Confidence Limit', kde=True, bins=30)
plt.title(f'Distribution of High and Low Confidence Limits for Class ID {class_id_with_max_cases}')
plt.xlabel('Confidence Limit')
plt.ylabel('Frequency')
plt.legend()
plt.show()
